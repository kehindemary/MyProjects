# %%
import pandas as pd

# %%
data = pd.read_csv('unemployment_rate.csv')

# %%
data
# Out:
#      country                                          indicator  \
# 0    Nigeria  LABOUR FORCE POPULATION (employment age and de...
# 1    Nigeria  LABOUR FORCE POPULATION (employment age and de...
# 2    Nigeria  LABOUR FORCE POPULATION (employment age and de...
# 3    Nigeria  LABOUR FORCE POPULATION (employment age and de...
# 4    Nigeria  LABOUR FORCE POPULATION (employment age and de...
# 5    Nigeria  LABOUR FORCE POPULATION (employment age and de...
# 6    Nigeria  LABOUR FORCE POPULATION (employment age and de...
# 7    Nigeria  LABOUR FORCE POPULATION (employment age and de...
# 8    Nigeria  LABOUR FORCE POPULATION (employment age and de...
# 9    Nigeria  LABOUR FORCE POPULATION (employment age and de...
# 10   Nigeria  LABOUR FORCE POPULATION (employment age and de...
# 11   Nigeria  LABOUR FORCE POPULATION (employment age and de...
# 12   Nigeria  LABOUR FORCE POPULATION (employment age and de...
# 13   Nigeria  LABOUR FORCE POPULATION (employment age and de...
# ...

# %%
Data1 = pd.read_csv('maleunemployment_rate.csv')

# %%
Data1
# Out:
#     country                                          indicator group     Unit  \
# 0   Nigeria  LABOUR FORCE POPULATION (employment age and de...  Male  Persons
# 1   Nigeria  LABOUR FORCE POPULATION (employment age and de...  Male  Persons
# 2   Nigeria  LABOUR FORCE POPULATION (employment age and de...  Male  Persons
# 3   Nigeria  LABOUR FORCE POPULATION (employment age and de...  Male  Persons
# 4   Nigeria  LABOUR FORCE POPULATION (employment age and de...  Male  Persons
# 5   Nigeria  LABOUR FORCE POPULATION (employment age and de...  Male  Persons
# 6   Nigeria  LABOUR FORCE POPULATION (employment age and de...  Male  Persons
# 7   Nigeria  LABOUR FORCE POPULATION (employment age and de...  Male  Persons
# 8   Nigeria  LABOUR FORCE POPULATION (employment age and de...  Male  Persons
# 9   Nigeria  LABOUR FORCE POPULATION (employment age and de...  Male  Persons
# 10  Nigeria  LABOUR FORCE POPULATION (employment age and de...  Male  Persons
# ...

# %%
data2 =  pd.read_csv('femaleunemployment_rate.csv')

# %%
data2
# Out:
#     country                                          indicator   group  \
# 0   Nigeria  LABOUR FORCE POPULATION (employment age and de...  Female
# 1   Nigeria  LABOUR FORCE POPULATION (employment age and de...  Female
# 2   Nigeria  LABOUR FORCE POPULATION (employment age and de...  Female
# 3   Nigeria  LABOUR FORCE POPULATION (employment age and de...  Female
# 4   Nigeria  LABOUR FORCE POPULATION (employment age and de...  Female
# 5   Nigeria  LABOUR FORCE POPULATION (employment age and de...  Female
# 6   Nigeria  LABOUR FORCE POPULATION (employment age and de...  Female
# 7   Nigeria  LABOUR FORCE POPULATION (employment age and de...  Female
# 8   Nigeria  LABOUR FORCE POPULATION (employment age and de...  Female
# 9   Nigeria  LABOUR FORCE POPULATION (employment age and de...  Female
# 10  Nigeria  LABOUR FORCE POPULATION (employment age and de...  Female
# 11  Nigeria  LABOUR FORCE POPULATION (employment age and de...  Female
# ...
